# %%
from google.colab import drive
drive.mount('/gdrive',force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.16.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4)

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 58.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 111.9 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.16.4 safetensors-0.3.1 tokenizers-0.13.3 transformers-4.31.0

# %%
import torch
from transformers import pipeline

generator = pipeline("text-generation", model="EleutherAI/polyglot-ko-3.8b", device=0, torch_dtype=torch.float16)
generator(
    "친구와 식사를 했다.",
    max_length=30,
    num_return_sequences=1,
)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/641 [00:00<?, ?B/s]
# Downloading (…)fetensors.index.json:   0%|          | 0.00/42.0k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Downloading (…)of-00008.safetensors:   0%|          | 0.00/957M [00:00<?, ?B/s]
# Downloading (…)of-00008.safetensors:   0%|          | 0.00/999M [00:00<?, ?B/s]
# Downloading (…)of-00008.safetensors:   0%|          | 0.00/1.00G [00:00<?, ?B/s]
# Downloading (…)of-00008.safetensors:   0%|          | 0.00/999M [00:00<?, ?B/s]
# Downloading (…)of-00008.safetensors:   0%|          | 0.00/999M [00:00<?, ?B/s]
# Downloading (…)of-00008.safetensors:   0%|          | 0.00/1.00G [00:00<?, ?B/s]
# Downloading (…)of-00008.safetensors:   0%|          | 0.00/999M [00:00<?, ?B/s]
# Downloading (…)of-00008.safetensors:   0%|          | 0.00/797M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/164 [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# [{'generated_text': '친구와 식사를 했다.\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b�'}]

# %%
generator(
    "한강에서 배를 탔다.",
    max_length=30,
    num_return_sequences=1,
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# [{'generated_text': '한강에서 배를 탔다. 배를 타고 가는 동안에는 한강의 아름다운 모습을 볼 수 있었다. 한강의 아름다운 모습'}]

# %%
generator(
    "남산에서 불꽃놀이를 한다.",
    max_length=60,
    num_return_sequences=1,
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# [{'generated_text': '남산에서 불꽃놀이를 한다. 남산타워에서 불꽃놀이를 하는 것은 처음이다. 남산타워에서 불꽃놀이를 하는 것은 처음이다. 남산타워에서 불꽃놀이를 하는 것은 처음이다. 남산타워에서 불꽃놀이를 하는 것은'}]

# %%
generator(
    "영화 어땠어?",
    max_length=60,
    num_return_sequences=1,
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# [{'generated_text': "영화 어땠어?'라는 질문을 받았을 때, '재미있었다'라고 대답하는 사람은 거의 없다. '재미있었다'라고 대답하는 사람은 '재미없었다'라고 대답하는 사람보다 더 많은 것을 알고"}]

# %%
generator(
    "아침 식사 후에 뭐 했니?",
    max_length=60,
    num_return_sequences=1,
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# [{'generated_text': '아침 식사 후에 뭐 했니?” “응, 산책했어.” “그래? 잘했다.” “응, 잘했어.” 10. 칭찬은 여러 번 해도 좋다. “넌 착하구나!” “너 착하구나!” “너 착하구나!'}]

# %%
generator(
    "네 이름은 어떻게 되니?",
    max_length=60,
    num_return_sequences=1,
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# [{'generated_text': '네 이름은 어떻게 되니?” “저는 ‘이’라고 합니다.” “이?” “예, 저는 이라고 합니다.” “이?” “예, 저는 이라고 합니다.” “이?” “예, 저는 이라고 합니다.”'}]

# %%
generator(
    "건강에 좋은 음식 좀 알려 줘.",
    max_length=60,
    num_return_sequences=1,
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# [{'generated_text': '건강에 좋은 음식 좀 알려 줘.” “네가 좋아하는 음식이 뭐야?” “난 고기를 좋아해.” “고기는 몸에 안 좋은데.” “그래도 고기를 먹어야 힘이 나.” “고기를 먹으면 힘이 나는 게'}]

# %%
pipe = pipeline('text-generation', model='beomi/kcgpt2', device=0, torch_dtype=torch.float16)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/872 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/525M [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.35M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/971k [00:00<?, ?B/s]

# %%
pipe("안녕")
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1369: UserWarning: Using `max_length`'s default (50) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# [{'generated_text': '안녕하세여!'}]

# %%
pipe("커피 한 잔")
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# [{'generated_text': '커피 한 잔만 마셔주면 더 살 수 있는데..그 돈 있으면 그냥 다른 걸로...'}]

# %%
pipe("저녁")
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# [{'generated_text': '저녁 8시까지라 해도 10시쯤 되면 다닥다닥 붙어앉아 밥 먹더라. 이게 거리두기 거리두기냐?'}]

# %%
pipe('인간처럼 생각하고, 행동하는 \'지능\'을 통해 인류가 이제까지 풀지 못했던')
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1369: UserWarning: Using `max_length`'s default (50) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# [{'generated_text': "인간처럼 생각하고, 행동하는 '지능'을 통해 인류가 이제까지 풀지 못했던 '인간성의 힘'을 습득해, 다시 인간을 성장시킬 수 있었다."}]

# %%
from transformers import pipeline

unmasker = pipeline("fill-mask", model="klue/bert-base")
unmasker("대한민국의 수도는 [MASK] 이다.")
# Out:
# Some weights of the model checkpoint at klue/bert-base were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [{'score': 0.5954672694206238,
#   'token': 3671,
#   'token_str': '서울',
#   'sequence': '대한민국의 수도는 서울 이다.'},
#  {'score': 0.08106347173452377,
#   'token': 9474,
#   'token_str': '광화문',
#   'sequence': '대한민국의 수도는 광화문 이다.'}]

# %%
from transformers import pipeline

unmasker = pipeline("fill-mask", model="klue/roberta-base")
unmasker("대한민국의 수도는 [MASK] 이다.", top_k=2)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/546 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/443M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/375 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/752k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# [{'score': 0.7481570839881897,
#   'token': 3671,
#   'token_str': '서울',
#   'sequence': '대한민국의 수도는 서울 이다.'},
#  {'score': 0.04424133896827698,
#   'token': 3902,
#   'token_str': '부산',
#   'sequence': '대한민국의 수도는 부산 이다.'}]

# %%
unmasker = pipeline("fill-mask", model="klue/roberta-base")
unmasker("대한민국의 대통령은 [MASK] 이다.", top_k=2)
# Out:
# [{'score': 0.6443962454795837,
#   'token': 5573,
#   'token_str': '문재인',
#   'sequence': '대한민국의 대통령은 문재인 이다.'},
#  {'score': 0.1350153535604477,
#   'token': 4655,
#   'token_str': '박근혜',
#   'sequence': '대한민국의 대통령은 박근혜 이다.'}]

# %%
unmasker = pipeline("fill-mask", model="klue/roberta-base")
unmasker("한국인의 평균수명은 [MASK] 이다.", top_k=2)
# Out:
# [{'score': 0.1217660903930664,
#   'token': 4684,
#   'token_str': '80',
#   'sequence': '한국인의 평균수명은 80 이다.'},
#  {'score': 0.06582559645175934,
#   'token': 4531,
#   'token_str': '70',
#   'sequence': '한국인의 평균수명은 70 이다.'}]

# %%
unmasker = pipeline("fill-mask", model="klue/roberta-base")
unmasker("한국의 제일 남쪽에 있는 섬의 이름은 [MASK] 이다.", top_k=2)
# Out:
# [{'score': 0.326756089925766,
#   'token': 8499,
#   'token_str': '독도',
#   'sequence': '한국의 제일 남쪽에 있는 섬의 이름은 독도 이다.'},
#  {'score': 0.0727405771613121,
#   'token': 1,
#   'token_str': '[PAD]',
#   'sequence': '한국의 제일 남쪽에 있는 섬의 이름은 이다.'}]

# %%
generator = pipeline("text-generation", model="skt/kogpt2-base-v2")
generator(
    "근육이 커지기 위해서는",
    max_length=128,
    num_return_sequences=1,
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# [{'generated_text': '근육이 커지기 위해서는 많은 사람이 노력해야 한다.\n그러자면 평소에 생활습관을 잘 관리하고 규칙적으로 운동을 해야 한다.\n일일 생활 중에는 음식 섭취량도 줄여야 한다.\n일일 식사 후 30분 이내로 걷기, 등산은 피하고 운동 후에는 스트레칭을 통해 근육을 강화하는 것이 좋으며, 규칙적으로 운동하기 위해서 근력운동을 꾸준히 해주면 근육이 강화될 수 있고 근육도 강화되는 효과를 얻을 수 있어 더 좋다.\n만족스러운 운동과 생활자세로 건강은 유지하지만 잘못된 생활습관을 방치하면 노약자와 심장질환자 등은 더욱 위험에 처하게 된다.\n오메가3 지방산은 우리 몸을 구성하는 단백질로서, 우리 몸의 대사과정에서 중요한 역할을 하고 있다.\n지방'}]

# %%
generator = pipeline("text-generation", model="skt/kogpt2-base-v2")
generator(
    "피부의 조직이 괴사된다면",
    max_length=128,
    num_return_sequences=1,
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [{'generated_text': '피부의 조직이 괴사된다면 그 부위를 절단할 필요가 있습니다.\n반드시 정확한 상처와 상처가 있는 부위를 먼저 절단해야 하는데 이를 제대로 하지 않으면 영구적인 손상인 만큼 제대로 된 진단 없이 섣불리 수술을 하기는 힘든 겁니다.\n때문에 예방이 잘 되지 않거나 회복이 불가능할 경우에는 적절한 치료를 받을 것을 추천합니다.\nMBC뉴스 김정환입니다.\nAll rights reserved. 내년부터 고소득·고가소득자 등의 부동산 가격이 급등하도록 유도하는 기획부동산 중개업자에 대한 제재기준이 대폭 강화된다.\n주택은 가격 담합시 최고 5000만원까지 부과된다.\n정부는 6일 서울 명동 은행회'}]

# %%
generator = pipeline("text-generation", model="skt/kogpt2-base-v2")
generator(
    "가장 좋은 건강법은",
    max_length=128,
    num_return_sequences=1,
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [{'generated_text': '가장 좋은 건강법은 바로 바른 식단이다.\n식사는 몸의 각 부위별로 조금씩 다르다.\n이런 점을 감안해 한 끼를 굶는 대신 하루 세 끼 식사를 하며 하루 세 끼 식사를 규칙적으로 유지하는 건 좋은 방법이다.\n하지만 아무리 식사를 줄이고 규칙적인 운동을 하면서 운동을 해도 체중은 늘 그대로 유지되므로 무리한 운동과 스트레칭으로 인한 체중 증가가 자칫 건강을 해치고 결국 건강을 해칠 수 있다.\n특히 최근릉을 비롯한 다이어트 운동가들은 무리한 운동과 스트레칭으로 인해 체중이 늘고 지방 흡수가 잘 되지 않아 다이어트에 성공했던 경우가 많다.\n이에 한의학과 전문의들은 체지방을 관리하는 식이요법과 운동요법을 처방했다.\n우선'}]

# %%
from transformers import pipeline
generator = pipeline("text-generation", model="skt/kogpt2-base-v2")
generator(
    "가장 좋은 한국어 문장 생성 언어 모델은",
    max_length=128,
    num_return_sequences=1,
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# [{'generated_text': '가장 좋은 한국어 문장 생성 언어 모델은 언어학 이론으로는 잘 이해되지 않는다. 인천에서 운행하는 광역버스 좌석버스를 무료로 이용할 수 있다.\n경기도 고양시 일산동과 고양시 고양시에서는 각각 15~15분 간격으로 광역버스와 마을버스가 운행된다.\n부산에서는 광역버스 좌석버스가 운행되고 있다.\n제주특별자치도에서는 제주시 오라동에서 18분 간격으로 광역버스와 마을버스가 운행된다.\n서울에서 부산으로 갈 수 있는 광역버스 좌석버스는 노선별로 각각 6~9분 간격으로 운행하는 방식이다.\n최저 이용료는 노선별 7000원, 1500원이며, 노선은 편도별로 다르다.\n서울'}]

# %%
from transformers import pipeline
import torch
generator = pipeline("text-generation", model="meta-llama/Llama-2-7b", device=0, torch_dtype=torch.float16)
generator(
    "가장 좋은 한국어 문장 생성 언어 모델은",
    max_length=128,
    num_return_sequences=1,
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     260     try:
# --> 261         response.raise_for_status()
#     262     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#     959         if http_error_msg:
# --> 960             raise HTTPError(http_error_msg, response=self)
#     961
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/meta-llama/Llama-2-7b/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash)
#     416         # Load from URL or cache if already cached
# --> 417         resolved_file = hf_hub_download(
#     418             path_or_repo_id,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     117
# --> 118         return fn(*args, **kwargs)
#     119
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout)
#    1194             try:
# -> 1195                 metadata = get_hf_file_metadata(
#    1196                     url=url,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     117
# --> 118         return fn(*args, **kwargs)
#     119
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in get_hf_file_metadata(url, token, proxies, timeout)
#    1540     )
# -> 1541     hf_raise_for_status(r)
#    1542
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     270             message = f"{response.status_code} Client Error." + "\n\n" + f"Entry Not Found for url: {response.url}."
# --> 271             raise EntryNotFoundError(message, response) from e
#     272
#
# EntryNotFoundError: 404 Client Error. (Request ID: Root=1-64c25a5f-21ae76201793dea818a1c3cd;7d308c32-88c1-4bdd-8c3e-a8eba042490c)
#
# Entry Not Found for url: https://huggingface.co/meta-llama/Llama-2-7b/resolve/main/config.json.
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-78823f2e92bb> in <cell line: 3>()
#       1 from transformers import pipeline
#       2 import torch
# ----> 3 generator = pipeline("text-generation", model="meta-llama/Llama-2-7b", device=0, torch_dtype=torch.float16)
#       4 generator(
#       5     "가장 좋은 한국어 문장 생성 언어 모델은",
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, use_auth_token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     703         hub_kwargs["_commit_hash"] = config._commit_hash
#     704     elif config is None and isinstance(model, str):
# --> 705         config = AutoConfig.from_pretrained(model, _from_pipeline=task, **hub_kwargs, **model_kwargs)
#     706         hub_kwargs["_commit_hash"] = config._commit_hash
#     707
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     981         kwargs["name_or_path"] = pretrained_model_name_or_path
#     982         trust_remote_code = kwargs.pop("trust_remote_code", None)
# --> 983         config_dict, unused_kwargs = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     984         has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#     985         has_local_code = "model_type" in config_dict and config_dict["model_type"] in CONFIG_MAPPING
#
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py in get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     615         original_kwargs = copy.deepcopy(kwargs)
#     616         # Get config dict associated with the base config file
# --> 617         config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     618         if "_commit_hash" in config_dict:
#     619             original_kwargs["_commit_hash"] = config_dict["_commit_hash"]
#
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py in _get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     670             try:
#     671                 # Load from local folder or from cache or download from model Hub and cache
# --> 672                 resolved_config_file = cached_file(
#     673                     pretrained_model_name_or_path,
#     674                     configuration_file,
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash)
#     461         if revision is None:
#     462             revision = "main"
# --> 463         raise EnvironmentError(
#     464             f"{path_or_repo_id} does not appear to have a file named {full_filename}. Checkout "
#     465             f"'https://huggingface.co/{path_or_repo_id}/{revision}' for available files."
#
# OSError: meta-llama/Llama-2-7b does not appear to have a file named config.json. Checkout 'https://huggingface.co/meta-llama/Llama-2-7b/main' for available files.

# %%
# !pip install accelerate -U
# Out:
# Collecting accelerate
#   Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.21.0

# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.16.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4)

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
